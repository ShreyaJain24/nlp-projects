# %%
import pickle
import itertools
import numpy as np
from scipy import spatial
from scipy.stats import norm
import nltk.data
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from nltk.corpus import reuters
from nltk. corpus import gutenberg
from nltk.corpus import brown
from nltk.tokenize import sent_tokenize
from gensim.models import KeyedVectors
from keras.layers import Input, Dense, Lambda, Layer
from keras import callbacks
from keras.models import Model
from keras import backend as K
from keras import metrics
# Out:
# Using TensorFlow backend.

# %%
w2v = KeyedVectors.load_word2vec_format('/Users/shreyajain/Downloads/datasets/wiki-news-300d-1M.vec')

# %%
def split_into_sent (text):
    strg = ''
    for word in text:
        strg += word
        strg += ' '
    strg_cleaned = strg.lower()
    for x in ['\xd5d','\n','"',"!", '#','$','%','&','(',')','*','+',',','-','/',':',';','<','=','>','?','@','[','^',']','_','`','{','|','}','~','\t']:
        strg_cleaned = strg_cleaned.replace(x, '')
    sentences = sent_tokenize(strg_cleaned)
    return sentences

# %%
a = split_into_sent (['A','man', 'in', 'white','runs', 'like', 'he','never','before','and','I','just','need','to'])
print ("texts ", a)
# Out:
# texts  ['a man in white runs like he never before and i just need to']

# %%
def vectorize_sentences(sentences):
    vectorized = []
    for sentence in sentences:
        byword = sentence.split()
        concat_vector = []
        for word in byword:
            try:
                concat_vector.append(w2v[word])
            except:
                pass
        vectorized.append(concat_vector)
    return vectorized

# %%
data_concat = []

for t in [brown.words(), reuters.words(), gutenberg.words()]:
    text = split_into_sent(t)
    vect = vectorize_sentences(text)
    data = [x for x in vect if len(x) == 10]
    for x in data:
        data_concat.append(list(itertools.chain.from_iterable(x)))

# with open ('/home/ubuntu/pynb/wikitokens.pickle', 'rb') as f:
#     wiki_tokens = pickle.load(f)
# wiki_tokens = vectorize_sentences(wiki_tokens)
# wikidata = [x for x in wiki_tokens if len(x) == 10]
# for x in wikidata:
#     data_concat.append(list(itertools.chain.from_iterable(x)))

# %%
data_array = np.array(data_concat)
np.random.shuffle(data_array)

# train = data_array[:8000]
# test = data_array[8000:10000]

train = data_array[:5000]
test = data_array[5000:6500]

# %%
# each element of train has 10 words (vectors of length 300 each)
print ("train ", train[0])
print ("train ", len(train[0]))

print ("test ", len(test))
# Out:
# train  [-0.0065 -0.033   0.006  ...  0.207   0.0689 -0.0467]
# train  3000
# test  1500

# %%
batch_size = 500
original_dim = 3000
latent_dim = 1000
intermediate_dim = 1200
epochs = 200
epsilon_std = 1.0

x = Input(batch_shape=(batch_size, original_dim))
h = Dense(intermediate_dim, activation='relu')(x)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

# re-parametrization trick
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,
                              stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# we instantiate these layers separately so as to reuse them later
decoder_h = Dense(intermediate_dim, activation='relu')
decoder_mean = Dense(original_dim, activation='sigmoid')
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# placeholder loss
def zero_loss(y_true, y_pred):
    return K.zeros_like(y_pred)

# Custom loss layer
class CustomVariationalLayer(Layer):
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomVariationalLayer, self).__init__(**kwargs)

    def vae_loss(self, x, x_decoded_mean):
        xent_loss = original_dim * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)

    def call(self, inputs):
        x = inputs[0]
        x_decoded_mean = inputs[1]
        loss = self.vae_loss(x, x_decoded_mean)
        self.add_loss(loss, inputs=inputs)
        # we don't use this output, but it has to have the correct shape:
        return K.ones_like(x)

loss_layer = CustomVariationalLayer()([x, x_decoded_mean])
vae = Model(x, [loss_layer])
vae.compile(optimizer='rmsprop', loss=[zero_loss])

#checkpoint
cp = [callbacks.ModelCheckpoint(filepath="/Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5", verbose=1, save_best_only=True)]

#train
vae.fit(train, train,
        shuffle=True,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(test, test), callbacks=cp)

# build a model to project inputs on the latent space
encoder = Model(x, z_mean)

# build a generator that can sample from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_h_decoded = decoder_h(decoder_input)
_x_decoded_mean = decoder_mean(_h_decoded)
generator = Model(decoder_input, _x_decoded_mean)
# Out:
# Train on 5000 samples, validate on 1500 samples
# Epoch 1/200
# 5000/5000 [==============================] - 4s 862us/step - loss: 131.1315 - val_loss: -456.2282
#
# Epoch 00001: val_loss improved from inf to -456.22819, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 2/200
# 5000/5000 [==============================] - 4s 714us/step - loss: -469.8772 - val_loss: -511.2983
#
# Epoch 00002: val_loss improved from -456.22819 to -511.29829, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 3/200
# 5000/5000 [==============================] - 4s 760us/step - loss: -511.2980 - val_loss: -523.8778
#
# Epoch 00003: val_loss improved from -511.29829 to -523.87779, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 4/200
# 5000/5000 [==============================] - 3s 684us/step - loss: -526.4622 - val_loss: -531.3965
#
# Epoch 00004: val_loss improved from -523.87779 to -531.39648, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 5/200
# 5000/5000 [==============================] - 4s 731us/step - loss: -534.4754 - val_loss: -541.9250
#
# Epoch 00005: val_loss improved from -531.39648 to -541.92503, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 6/200
# 5000/5000 [==============================] - 4s 708us/step - loss: -543.7319 - val_loss: -546.5421
#
# Epoch 00006: val_loss improved from -541.92503 to -546.54205, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 7/200
# 5000/5000 [==============================] - 3s 698us/step - loss: -551.5453 - val_loss: -552.1888
#
# Epoch 00007: val_loss improved from -546.54205 to -552.18882, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 8/200
# 5000/5000 [==============================] - 3s 693us/step - loss: -558.7763 - val_loss: -555.6006
#
# Epoch 00008: val_loss improved from -552.18882 to -555.60057, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 9/200
# 5000/5000 [==============================] - 3s 687us/step - loss: -561.5815 - val_loss: -562.3528
#
# Epoch 00009: val_loss improved from -555.60057 to -562.35280, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 10/200
# 5000/5000 [==============================] - 3s 682us/step - loss: -567.5248 - val_loss: -568.6030
#
# Epoch 00010: val_loss improved from -562.35280 to -568.60299, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 11/200
# 5000/5000 [==============================] - 3s 688us/step - loss: -571.8241 - val_loss: -575.3481
#
# Epoch 00011: val_loss improved from -568.60299 to -575.34812, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 12/200
# 5000/5000 [==============================] - 3s 685us/step - loss: -585.2652 - val_loss: -593.6573
#
# Epoch 00012: val_loss improved from -575.34812 to -593.65729, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 13/200
# 5000/5000 [==============================] - 3s 679us/step - loss: -599.0708 - val_loss: -603.5803
#
# Epoch 00013: val_loss improved from -593.65729 to -603.58026, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 14/200
# 5000/5000 [==============================] - 3s 682us/step - loss: -606.4972 - val_loss: -608.3477
#
# Epoch 00014: val_loss improved from -603.58026 to -608.34766, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 15/200
# 5000/5000 [==============================] - 3s 686us/step - loss: -610.8750 - val_loss: -609.1764
#
# Epoch 00015: val_loss improved from -608.34766 to -609.17635, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 16/200
# 5000/5000 [==============================] - 3s 683us/step - loss: -613.4138 - val_loss: -612.6694
#
# Epoch 00016: val_loss improved from -609.17635 to -612.66937, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 17/200
# 5000/5000 [==============================] - 3s 684us/step - loss: -615.1185 - val_loss: -613.5533
#
# Epoch 00017: val_loss improved from -612.66937 to -613.55328, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 18/200
# 5000/5000 [==============================] - 3s 683us/step - loss: -616.4274 - val_loss: -614.8018
#
# Epoch 00018: val_loss improved from -613.55328 to -614.80184, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 19/200
# 5000/5000 [==============================] - 3s 663us/step - loss: -617.2654 - val_loss: -616.8858
#
# Epoch 00019: val_loss improved from -614.80184 to -616.88584, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 20/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -618.9529 - val_loss: -618.2888
#
# Epoch 00020: val_loss improved from -616.88584 to -618.28876, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 21/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -620.0125 - val_loss: -619.0317
#
# Epoch 00021: val_loss improved from -618.28876 to -619.03168, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 22/200
# 5000/5000 [==============================] - 3s 635us/step - loss: -621.1438 - val_loss: -619.7311
#
# Epoch 00022: val_loss improved from -619.03168 to -619.73114, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 23/200
# 5000/5000 [==============================] - 3s 647us/step - loss: -622.4457 - val_loss: -617.8707
#
# Epoch 00023: val_loss did not improve from -619.73114
# Epoch 24/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -623.8479 - val_loss: -620.6010
#
# Epoch 00024: val_loss improved from -619.73114 to -620.60097, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 25/200
# 5000/5000 [==============================] - 3s 631us/step - loss: -624.6501 - val_loss: -622.6212
#
# Epoch 00025: val_loss improved from -620.60097 to -622.62118, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 26/200
# 5000/5000 [==============================] - 3s 639us/step - loss: -625.6940 - val_loss: -624.8979
#
# Epoch 00026: val_loss improved from -622.62118 to -624.89795, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 27/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -626.8977 - val_loss: -625.2136
#
# Epoch 00027: val_loss improved from -624.89795 to -625.21362, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 28/200
# 5000/5000 [==============================] - 3s 625us/step - loss: -628.1751 - val_loss: -625.8149
#
# Epoch 00028: val_loss improved from -625.21362 to -625.81494, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 29/200
# 5000/5000 [==============================] - 3s 631us/step - loss: -629.7027 - val_loss: -626.3699
#
# Epoch 00029: val_loss improved from -625.81494 to -626.36993, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 30/200
# 5000/5000 [==============================] - 3s 635us/step - loss: -630.6833 - val_loss: -628.8255
#
# Epoch 00030: val_loss improved from -626.36993 to -628.82550, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 31/200
# 5000/5000 [==============================] - 3s 633us/step - loss: -632.2362 - val_loss: -629.3515
#
# Epoch 00031: val_loss improved from -628.82550 to -629.35150, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 32/200
# 5000/5000 [==============================] - 3s 639us/step - loss: -633.7070 - val_loss: -630.3504
#
# Epoch 00032: val_loss improved from -629.35150 to -630.35040, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 33/200
# 5000/5000 [==============================] - 3s 637us/step - loss: -635.3070 - val_loss: -631.9758
#
# Epoch 00033: val_loss improved from -630.35040 to -631.97579, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 34/200
# 5000/5000 [==============================] - 3s 634us/step - loss: -636.6880 - val_loss: -634.8375
#
# Epoch 00034: val_loss improved from -631.97579 to -634.83748, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 35/200
# 5000/5000 [==============================] - 3s 627us/step - loss: -638.0566 - val_loss: -634.3634
#
# Epoch 00035: val_loss did not improve from -634.83748
# Epoch 36/200
# 5000/5000 [==============================] - 3s 637us/step - loss: -639.1839 - val_loss: -635.8832
#
# Epoch 00036: val_loss improved from -634.83748 to -635.88320, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 37/200
# 5000/5000 [==============================] - 3s 629us/step - loss: -640.5502 - val_loss: -636.9641
#
# Epoch 00037: val_loss improved from -635.88320 to -636.96407, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 38/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -641.5497 - val_loss: -637.8291
#
# Epoch 00038: val_loss improved from -636.96407 to -637.82914, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 39/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -642.9861 - val_loss: -638.0701
#
# Epoch 00039: val_loss improved from -637.82914 to -638.07007, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 40/200
# 5000/5000 [==============================] - 3s 637us/step - loss: -643.2787 - val_loss: -640.2323
#
# Epoch 00040: val_loss improved from -638.07007 to -640.23226, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 41/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -644.9238 - val_loss: -640.9084
#
# Epoch 00041: val_loss improved from -640.23226 to -640.90845, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 42/200
# 5000/5000 [==============================] - 3s 650us/step - loss: -645.6023 - val_loss: -641.4717
#
# Epoch 00042: val_loss improved from -640.90845 to -641.47168, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 43/200
# 5000/5000 [==============================] - 3s 639us/step - loss: -646.5489 - val_loss: -640.5038
#
# Epoch 00043: val_loss did not improve from -641.47168
# Epoch 44/200
# 5000/5000 [==============================] - 3s 647us/step - loss: -647.7623 - val_loss: -641.1994
#
# Epoch 00044: val_loss did not improve from -641.47168
# Epoch 45/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -648.2577 - val_loss: -644.4577
#
# Epoch 00045: val_loss improved from -641.47168 to -644.45770, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 46/200
# 5000/5000 [==============================] - 3s 634us/step - loss: -649.2710 - val_loss: -644.6043
#
# Epoch 00046: val_loss improved from -644.45770 to -644.60429, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 47/200
# 5000/5000 [==============================] - 3s 634us/step - loss: -650.0768 - val_loss: -645.5505
#
# Epoch 00047: val_loss improved from -644.60429 to -645.55054, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 48/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -650.9940 - val_loss: -645.9803
#
# Epoch 00048: val_loss improved from -645.55054 to -645.98031, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 49/200
# 5000/5000 [==============================] - 3s 635us/step - loss: -652.1566 - val_loss: -646.7784
#
# Epoch 00049: val_loss improved from -645.98031 to -646.77836, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 50/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -652.2637 - val_loss: -646.7265
#
# Epoch 00050: val_loss did not improve from -646.77836
# Epoch 51/200
# 5000/5000 [==============================] - 3s 645us/step - loss: -653.4977 - val_loss: -648.4185
#
# Epoch 00051: val_loss improved from -646.77836 to -648.41854, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 52/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -654.4427 - val_loss: -648.3965
#
# Epoch 00052: val_loss did not improve from -648.41854
# Epoch 53/200
# 5000/5000 [==============================] - 3s 639us/step - loss: -654.9595 - val_loss: -649.9591
#
# Epoch 00053: val_loss improved from -648.41854 to -649.95911, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 54/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -656.0136 - val_loss: -649.5101
#
# Epoch 00054: val_loss did not improve from -649.95911
# Epoch 55/200
# 5000/5000 [==============================] - 3s 648us/step - loss: -656.7608 - val_loss: -649.4883
#
# Epoch 00055: val_loss did not improve from -649.95911
# Epoch 56/200
# 5000/5000 [==============================] - 3s 646us/step - loss: -657.3237 - val_loss: -651.0393
#
# Epoch 00056: val_loss improved from -649.95911 to -651.03933, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 57/200
# 5000/5000 [==============================] - 3s 637us/step - loss: -658.8455 - val_loss: -651.4223
#
# Epoch 00057: val_loss improved from -651.03933 to -651.42230, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 58/200
# 5000/5000 [==============================] - 3s 640us/step - loss: -658.6113 - val_loss: -652.7200
#
# Epoch 00058: val_loss improved from -651.42230 to -652.71997, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 59/200
# 5000/5000 [==============================] - 3s 647us/step - loss: -660.5069 - val_loss: -653.6295
#
# Epoch 00059: val_loss improved from -652.71997 to -653.62948, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 60/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -659.7118 - val_loss: -655.2195
#
# Epoch 00060: val_loss improved from -653.62948 to -655.21952, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 61/200
# 5000/5000 [==============================] - 3s 637us/step - loss: -661.4648 - val_loss: -655.2196
#
# Epoch 00061: val_loss improved from -655.21952 to -655.21958, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 62/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -661.9036 - val_loss: -654.4835
#
# Epoch 00062: val_loss did not improve from -655.21958
# Epoch 63/200
# 5000/5000 [==============================] - 3s 649us/step - loss: -662.1777 - val_loss: -656.2673
#
# Epoch 00063: val_loss improved from -655.21958 to -656.26733, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 64/200
# 5000/5000 [==============================] - 3s 635us/step - loss: -663.6131 - val_loss: -656.3464
#
# Epoch 00064: val_loss improved from -656.26733 to -656.34644, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 65/200
# 5000/5000 [==============================] - 3s 635us/step - loss: -664.1250 - val_loss: -657.9270
#
# Epoch 00065: val_loss improved from -656.34644 to -657.92704, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 66/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -664.6593 - val_loss: -655.5481
#
# Epoch 00066: val_loss did not improve from -657.92704
# Epoch 67/200
# 5000/5000 [==============================] - 3s 669us/step - loss: -665.3027 - val_loss: -657.9743
#
# Epoch 00067: val_loss improved from -657.92704 to -657.97426, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 68/200
# 5000/5000 [==============================] - 3s 644us/step - loss: -666.1211 - val_loss: -657.5524
#
# Epoch 00068: val_loss did not improve from -657.97426
# Epoch 69/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -666.6739 - val_loss: -659.7467
#
# Epoch 00069: val_loss improved from -657.97426 to -659.74670, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 70/200
# 5000/5000 [==============================] - 3s 670us/step - loss: -667.3727 - val_loss: -660.3977
#
# Epoch 00070: val_loss improved from -659.74670 to -660.39771, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 71/200
# 5000/5000 [==============================] - 4s 728us/step - loss: -668.5383 - val_loss: -661.2513
#
# Epoch 00071: val_loss improved from -660.39771 to -661.25130, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 72/200
# 5000/5000 [==============================] - 3s 647us/step - loss: -669.1799 - val_loss: -661.3734
#
# Epoch 00072: val_loss improved from -661.25130 to -661.37343, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 73/200
# 5000/5000 [==============================] - 3s 629us/step - loss: -669.9694 - val_loss: -661.3207
#
# Epoch 00073: val_loss did not improve from -661.37343
# Epoch 74/200
# 5000/5000 [==============================] - 3s 650us/step - loss: -670.0661 - val_loss: -663.0027
#
# Epoch 00074: val_loss improved from -661.37343 to -663.00275, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 75/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -671.6450 - val_loss: -664.5266
#
# Epoch 00075: val_loss improved from -663.00275 to -664.52655, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 76/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -671.7864 - val_loss: -664.5305
#
# Epoch 00076: val_loss improved from -664.52655 to -664.53050, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 77/200
# 5000/5000 [==============================] - 3s 640us/step - loss: -672.1287 - val_loss: -662.8615
#
# Epoch 00077: val_loss did not improve from -664.53050
# Epoch 78/200
# 5000/5000 [==============================] - 3s 650us/step - loss: -672.8659 - val_loss: -665.0105
#
# Epoch 00078: val_loss improved from -664.53050 to -665.01052, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 79/200
# 5000/5000 [==============================] - 3s 644us/step - loss: -674.1623 - val_loss: -665.4013
#
# Epoch 00079: val_loss improved from -665.01052 to -665.40127, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 80/200
# 5000/5000 [==============================] - 3s 634us/step - loss: -674.5446 - val_loss: -665.0370
#
# Epoch 00080: val_loss did not improve from -665.40127
# Epoch 81/200
# 5000/5000 [==============================] - 3s 644us/step - loss: -675.0058 - val_loss: -665.2913
#
# Epoch 00081: val_loss did not improve from -665.40127
# Epoch 82/200
# 5000/5000 [==============================] - 3s 651us/step - loss: -675.9021 - val_loss: -667.4973
#
# Epoch 00082: val_loss improved from -665.40127 to -667.49731, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 83/200
# 5000/5000 [==============================] - 3s 662us/step - loss: -676.7338 - val_loss: -668.1900
#
# Epoch 00083: val_loss improved from -667.49731 to -668.19000, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 84/200
# 5000/5000 [==============================] - 3s 681us/step - loss: -678.0663 - val_loss: -667.6803
#
# Epoch 00084: val_loss did not improve from -668.19000
# Epoch 85/200
# 5000/5000 [==============================] - 3s 663us/step - loss: -678.2244 - val_loss: -669.0421
#
# Epoch 00085: val_loss improved from -668.19000 to -669.04205, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 86/200
# 5000/5000 [==============================] - 3s 635us/step - loss: -678.1572 - val_loss: -669.9619
#
# Epoch 00086: val_loss improved from -669.04205 to -669.96193, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 87/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -679.8507 - val_loss: -669.7292
#
# Epoch 00087: val_loss did not improve from -669.96193
# Epoch 88/200
# 5000/5000 [==============================] - 3s 642us/step - loss: -680.2368 - val_loss: -670.4354
#
# Epoch 00088: val_loss improved from -669.96193 to -670.43545, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 89/200
# 5000/5000 [==============================] - 3s 649us/step - loss: -680.2168 - val_loss: -671.4713
#
# Epoch 00089: val_loss improved from -670.43545 to -671.47131, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 90/200
# 5000/5000 [==============================] - 3s 673us/step - loss: -681.3444 - val_loss: -671.3003
#
# Epoch 00090: val_loss did not improve from -671.47131
# Epoch 91/200
# 5000/5000 [==============================] - 4s 702us/step - loss: -682.7082 - val_loss: -672.8722
#
# Epoch 00091: val_loss improved from -671.47131 to -672.87221, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 92/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -682.3889 - val_loss: -671.6721
#
# Epoch 00092: val_loss did not improve from -672.87221
# Epoch 93/200
# 5000/5000 [==============================] - 3s 644us/step - loss: -683.6843 - val_loss: -673.5475
#
# Epoch 00093: val_loss improved from -672.87221 to -673.54755, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 94/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -684.1188 - val_loss: -673.9003
#
# Epoch 00094: val_loss improved from -673.54755 to -673.90035, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 95/200
# 5000/5000 [==============================] - 3s 646us/step - loss: -684.3944 - val_loss: -673.6636
#
# Epoch 00095: val_loss did not improve from -673.90035
# Epoch 96/200
# 5000/5000 [==============================] - 3s 680us/step - loss: -685.5161 - val_loss: -673.9981
#
# Epoch 00096: val_loss improved from -673.90035 to -673.99809, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 97/200
# 5000/5000 [==============================] - 3s 639us/step - loss: -685.2719 - val_loss: -674.4280
#
# Epoch 00097: val_loss improved from -673.99809 to -674.42800, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 98/200
# 5000/5000 [==============================] - 3s 639us/step - loss: -686.2872 - val_loss: -675.4914
#
# Epoch 00098: val_loss improved from -674.42800 to -675.49135, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 99/200
# 5000/5000 [==============================] - 3s 651us/step - loss: -686.6322 - val_loss: -676.2124
#
# Epoch 00099: val_loss improved from -675.49135 to -676.21238, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 100/200
# 5000/5000 [==============================] - 3s 646us/step - loss: -687.2398 - val_loss: -674.7639
#
# Epoch 00100: val_loss did not improve from -676.21238
# Epoch 101/200
# 5000/5000 [==============================] - 3s 672us/step - loss: -687.3810 - val_loss: -676.6370
#
# Epoch 00101: val_loss improved from -676.21238 to -676.63702, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 102/200
# 5000/5000 [==============================] - 3s 658us/step - loss: -688.4713 - val_loss: -677.5512
#
# Epoch 00102: val_loss improved from -676.63702 to -677.55123, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 103/200
# 5000/5000 [==============================] - 3s 631us/step - loss: -688.4710 - val_loss: -675.9485
#
# Epoch 00103: val_loss did not improve from -677.55123
# Epoch 104/200
# 5000/5000 [==============================] - 3s 673us/step - loss: -689.5594 - val_loss: -676.3359
#
# Epoch 00104: val_loss did not improve from -677.55123
# Epoch 105/200
# 5000/5000 [==============================] - 3s 676us/step - loss: -689.7091 - val_loss: -677.4855
#
# Epoch 00105: val_loss did not improve from -677.55123
# Epoch 106/200
# 5000/5000 [==============================] - 3s 664us/step - loss: -690.1627 - val_loss: -679.0202
#
# Epoch 00106: val_loss improved from -677.55123 to -679.02020, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 107/200
# 5000/5000 [==============================] - 3s 661us/step - loss: -690.8946 - val_loss: -679.1258
#
# Epoch 00107: val_loss improved from -679.02020 to -679.12575, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 108/200
# 5000/5000 [==============================] - 3s 645us/step - loss: -691.4769 - val_loss: -678.9138
#
# Epoch 00108: val_loss did not improve from -679.12575
# Epoch 109/200
# 5000/5000 [==============================] - 3s 660us/step - loss: -692.2392 - val_loss: -678.9391
#
# Epoch 00109: val_loss did not improve from -679.12575
# Epoch 110/200
# 5000/5000 [==============================] - 3s 668us/step - loss: -692.5594 - val_loss: -679.7871
#
# Epoch 00110: val_loss improved from -679.12575 to -679.78713, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 111/200
# 5000/5000 [==============================] - 3s 659us/step - loss: -692.5007 - val_loss: -680.7688
#
# Epoch 00111: val_loss improved from -679.78713 to -680.76876, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 112/200
# 5000/5000 [==============================] - 3s 663us/step - loss: -693.8370 - val_loss: -681.2540
#
# Epoch 00112: val_loss improved from -680.76876 to -681.25399, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 113/200
# 5000/5000 [==============================] - 3s 646us/step - loss: -694.3920 - val_loss: -680.8376
#
# Epoch 00113: val_loss did not improve from -681.25399
# Epoch 114/200
# 5000/5000 [==============================] - 3s 680us/step - loss: -694.5376 - val_loss: -681.5683
#
# Epoch 00114: val_loss improved from -681.25399 to -681.56830, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 115/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -695.7438 - val_loss: -681.7804
#
# Epoch 00115: val_loss improved from -681.56830 to -681.78038, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 116/200
# 5000/5000 [==============================] - 3s 657us/step - loss: -695.6840 - val_loss: -683.0617
#
# Epoch 00116: val_loss improved from -681.78038 to -683.06173, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 117/200
# 5000/5000 [==============================] - 3s 653us/step - loss: -696.3715 - val_loss: -682.7026
#
# Epoch 00117: val_loss did not improve from -683.06173
# Epoch 118/200
# 5000/5000 [==============================] - 3s 670us/step - loss: -696.5064 - val_loss: -683.2199
#
# Epoch 00118: val_loss improved from -683.06173 to -683.21991, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 119/200
# 5000/5000 [==============================] - 3s 664us/step - loss: -696.7835 - val_loss: -680.9704
#
# Epoch 00119: val_loss did not improve from -683.21991
# Epoch 120/200
# 5000/5000 [==============================] - 3s 649us/step - loss: -697.3703 - val_loss: -683.2730
#
# Epoch 00120: val_loss improved from -683.21991 to -683.27303, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 121/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -698.0861 - val_loss: -683.9853
#
# Epoch 00121: val_loss improved from -683.27303 to -683.98533, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 122/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -699.1115 - val_loss: -685.2000
#
# Epoch 00122: val_loss improved from -683.98533 to -685.19995, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 123/200
# 5000/5000 [==============================] - 3s 634us/step - loss: -699.3023 - val_loss: -683.4999
#
# Epoch 00123: val_loss did not improve from -685.19995
# Epoch 124/200
# 5000/5000 [==============================] - 3s 651us/step - loss: -699.7372 - val_loss: -685.1131
#
# Epoch 00124: val_loss did not improve from -685.19995
# Epoch 125/200
# 5000/5000 [==============================] - 3s 652us/step - loss: -699.7939 - val_loss: -685.1787
#
# Epoch 00125: val_loss did not improve from -685.19995
# Epoch 126/200
# 5000/5000 [==============================] - 3s 658us/step - loss: -700.8884 - val_loss: -686.3647
#
# Epoch 00126: val_loss improved from -685.19995 to -686.36473, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 127/200
# 5000/5000 [==============================] - 3s 666us/step - loss: -701.0990 - val_loss: -686.9353
#
# Epoch 00127: val_loss improved from -686.36473 to -686.93534, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 128/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -702.0330 - val_loss: -684.9541
#
# Epoch 00128: val_loss did not improve from -686.93534
# Epoch 129/200
# 5000/5000 [==============================] - 3s 652us/step - loss: -701.6543 - val_loss: -687.1875
#
# Epoch 00129: val_loss improved from -686.93534 to -687.18748, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 130/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -702.4521 - val_loss: -686.4699
#
# Epoch 00130: val_loss did not improve from -687.18748
# Epoch 131/200
# 5000/5000 [==============================] - 3s 648us/step - loss: -702.6913 - val_loss: -687.0161
#
# Epoch 00131: val_loss did not improve from -687.18748
# Epoch 132/200
# 5000/5000 [==============================] - 3s 653us/step - loss: -703.3998 - val_loss: -687.7015
#
# Epoch 00132: val_loss improved from -687.18748 to -687.70150, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 133/200
# 5000/5000 [==============================] - 3s 632us/step - loss: -703.7378 - val_loss: -687.7008
#
# Epoch 00133: val_loss did not improve from -687.70150
# Epoch 134/200
# 5000/5000 [==============================] - 3s 645us/step - loss: -704.4461 - val_loss: -688.4708
#
# Epoch 00134: val_loss improved from -687.70150 to -688.47085, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 135/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -704.9158 - val_loss: -688.0455
#
# Epoch 00135: val_loss did not improve from -688.47085
# Epoch 136/200
# 5000/5000 [==============================] - 3s 669us/step - loss: -704.6215 - val_loss: -689.1046
#
# Epoch 00136: val_loss improved from -688.47085 to -689.10457, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 137/200
# 5000/5000 [==============================] - 3s 649us/step - loss: -705.8502 - val_loss: -688.4052
#
# Epoch 00137: val_loss did not improve from -689.10457
# Epoch 138/200
# 5000/5000 [==============================] - 3s 654us/step - loss: -705.7498 - val_loss: -690.1332
#
# Epoch 00138: val_loss improved from -689.10457 to -690.13316, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 139/200
# 5000/5000 [==============================] - 3s 653us/step - loss: -706.1546 - val_loss: -689.9310
#
# Epoch 00139: val_loss did not improve from -690.13316
# Epoch 140/200
# 5000/5000 [==============================] - 3s 661us/step - loss: -706.6137 - val_loss: -690.7072
#
# Epoch 00140: val_loss improved from -690.13316 to -690.70717, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 141/200
# 5000/5000 [==============================] - 3s 653us/step - loss: -707.6718 - val_loss: -690.8196
#
# Epoch 00141: val_loss improved from -690.70717 to -690.81956, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 142/200
# 5000/5000 [==============================] - 3s 668us/step - loss: -707.9937 - val_loss: -690.8154
#
# Epoch 00142: val_loss did not improve from -690.81956
# Epoch 143/200
# 5000/5000 [==============================] - 3s 660us/step - loss: -708.1647 - val_loss: -691.6498
#
# Epoch 00143: val_loss improved from -690.81956 to -691.64978, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 144/200
# 5000/5000 [==============================] - 3s 646us/step - loss: -707.8947 - val_loss: -691.0449
#
# Epoch 00144: val_loss did not improve from -691.64978
# Epoch 145/200
# 5000/5000 [==============================] - 3s 661us/step - loss: -709.0332 - val_loss: -690.9403
#
# Epoch 00145: val_loss did not improve from -691.64978
# Epoch 146/200
# 5000/5000 [==============================] - 3s 665us/step - loss: -709.5570 - val_loss: -692.4138
#
# Epoch 00146: val_loss improved from -691.64978 to -692.41382, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 147/200
# 5000/5000 [==============================] - 3s 645us/step - loss: -709.0366 - val_loss: -692.9774
#
# Epoch 00147: val_loss improved from -692.41382 to -692.97738, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 148/200
# 5000/5000 [==============================] - 3s 678us/step - loss: -710.4572 - val_loss: -693.7309
#
# Epoch 00148: val_loss improved from -692.97738 to -693.73094, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 149/200
# 5000/5000 [==============================] - 3s 643us/step - loss: -711.0263 - val_loss: -692.4698
#
# Epoch 00149: val_loss did not improve from -693.73094
# Epoch 150/200
# 5000/5000 [==============================] - 3s 660us/step - loss: -710.4015 - val_loss: -692.6738
#
# Epoch 00150: val_loss did not improve from -693.73094
# Epoch 151/200
# 5000/5000 [==============================] - 3s 649us/step - loss: -711.2650 - val_loss: -693.1123
#
# Epoch 00151: val_loss did not improve from -693.73094
# Epoch 152/200
# 5000/5000 [==============================] - 3s 654us/step - loss: -712.2310 - val_loss: -694.2178
#
# Epoch 00152: val_loss improved from -693.73094 to -694.21777, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 153/200
# 5000/5000 [==============================] - 3s 637us/step - loss: -712.0750 - val_loss: -693.7631
#
# Epoch 00153: val_loss did not improve from -694.21777
# Epoch 154/200
# 5000/5000 [==============================] - 3s 649us/step - loss: -712.3592 - val_loss: -694.5268
#
# Epoch 00154: val_loss improved from -694.21777 to -694.52677, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 155/200
# 5000/5000 [==============================] - 3s 645us/step - loss: -713.0253 - val_loss: -692.2909
#
# Epoch 00155: val_loss did not improve from -694.52677
# Epoch 156/200
# 5000/5000 [==============================] - 3s 674us/step - loss: -712.9276 - val_loss: -693.9253
#
# Epoch 00156: val_loss did not improve from -694.52677
# Epoch 157/200
# 5000/5000 [==============================] - 3s 666us/step - loss: -713.4173 - val_loss: -695.1492
#
# Epoch 00157: val_loss improved from -694.52677 to -695.14919, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 158/200
# 5000/5000 [==============================] - 3s 645us/step - loss: -714.1652 - val_loss: -695.0139
#
# Epoch 00158: val_loss did not improve from -695.14919
# Epoch 159/200
# 5000/5000 [==============================] - 3s 655us/step - loss: -714.5677 - val_loss: -696.3981
#
# Epoch 00159: val_loss improved from -695.14919 to -696.39807, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 160/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -714.9977 - val_loss: -695.8220
#
# Epoch 00160: val_loss did not improve from -696.39807
# Epoch 161/200
# 5000/5000 [==============================] - 3s 652us/step - loss: -714.4209 - val_loss: -694.7094
#
# Epoch 00161: val_loss did not improve from -696.39807
# Epoch 162/200
# 5000/5000 [==============================] - 3s 654us/step - loss: -715.8213 - val_loss: -696.6789
#
# Epoch 00162: val_loss improved from -696.39807 to -696.67885, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 163/200
# 5000/5000 [==============================] - 3s 656us/step - loss: -715.8643 - val_loss: -695.1689
#
# Epoch 00163: val_loss did not improve from -696.67885
# Epoch 164/200
# 5000/5000 [==============================] - 3s 662us/step - loss: -716.2908 - val_loss: -694.2998
#
# Epoch 00164: val_loss did not improve from -696.67885
# Epoch 165/200
# 5000/5000 [==============================] - 3s 658us/step - loss: -716.4323 - val_loss: -696.4748
#
# Epoch 00165: val_loss did not improve from -696.67885
# Epoch 166/200
# 5000/5000 [==============================] - 3s 644us/step - loss: -716.7583 - val_loss: -697.2564
#
# Epoch 00166: val_loss improved from -696.67885 to -697.25645, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 167/200
# 5000/5000 [==============================] - 3s 642us/step - loss: -716.9620 - val_loss: -698.0582
#
# Epoch 00167: val_loss improved from -697.25645 to -698.05821, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 168/200
# 5000/5000 [==============================] - 3s 633us/step - loss: -717.5988 - val_loss: -697.4574
#
# Epoch 00168: val_loss did not improve from -698.05821
# Epoch 169/200
# 5000/5000 [==============================] - 3s 647us/step - loss: -718.2663 - val_loss: -697.8699
#
# Epoch 00169: val_loss did not improve from -698.05821
# Epoch 170/200
# 5000/5000 [==============================] - 3s 638us/step - loss: -718.4020 - val_loss: -697.7162
#
# Epoch 00170: val_loss did not improve from -698.05821
# Epoch 171/200
# 5000/5000 [==============================] - 3s 658us/step - loss: -718.7561 - val_loss: -696.8721
#
# Epoch 00171: val_loss did not improve from -698.05821
# Epoch 172/200
# 5000/5000 [==============================] - 3s 653us/step - loss: -719.0156 - val_loss: -697.9742
#
# Epoch 00172: val_loss did not improve from -698.05821
# Epoch 173/200
# 5000/5000 [==============================] - 3s 642us/step - loss: -719.5341 - val_loss: -696.8399
#
# Epoch 00173: val_loss did not improve from -698.05821
# Epoch 174/200
# 5000/5000 [==============================] - 3s 665us/step - loss: -719.9376 - val_loss: -697.3519
#
# Epoch 00174: val_loss did not improve from -698.05821
# Epoch 175/200
# 5000/5000 [==============================] - 3s 655us/step - loss: -719.9396 - val_loss: -698.5073
#
# Epoch 00175: val_loss improved from -698.05821 to -698.50728, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 176/200
# 5000/5000 [==============================] - 3s 657us/step - loss: -720.8199 - val_loss: -699.5455
#
# Epoch 00176: val_loss improved from -698.50728 to -699.54553, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 177/200
# 5000/5000 [==============================] - 3s 665us/step - loss: -721.0701 - val_loss: -698.9771
#
# Epoch 00177: val_loss did not improve from -699.54553
# Epoch 178/200
# 5000/5000 [==============================] - 3s 659us/step - loss: -721.6100 - val_loss: -699.0572
#
# Epoch 00178: val_loss did not improve from -699.54553
# Epoch 179/200
# 5000/5000 [==============================] - 3s 658us/step - loss: -721.8346 - val_loss: -698.7695
#
# Epoch 00179: val_loss did not improve from -699.54553
# Epoch 180/200
# 5000/5000 [==============================] - 3s 656us/step - loss: -721.6718 - val_loss: -699.6982
#
# Epoch 00180: val_loss improved from -699.54553 to -699.69820, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 181/200
# 5000/5000 [==============================] - 3s 636us/step - loss: -722.3901 - val_loss: -700.2706
#
# Epoch 00181: val_loss improved from -699.69820 to -700.27061, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 182/200
# 5000/5000 [==============================] - 3s 682us/step - loss: -723.4526 - val_loss: -700.3920
#
# Epoch 00182: val_loss improved from -700.27061 to -700.39203, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 183/200
# 5000/5000 [==============================] - 3s 648us/step - loss: -722.9913 - val_loss: -700.5941
#
# Epoch 00183: val_loss improved from -700.39203 to -700.59410, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 184/200
# 5000/5000 [==============================] - 3s 677us/step - loss: -723.2286 - val_loss: -700.4358
#
# Epoch 00184: val_loss did not improve from -700.59410
# Epoch 185/200
# 5000/5000 [==============================] - 3s 669us/step - loss: -723.8650 - val_loss: -700.4455
#
# Epoch 00185: val_loss did not improve from -700.59410
# Epoch 186/200
# 5000/5000 [==============================] - 3s 665us/step - loss: -724.1541 - val_loss: -699.3916
#
# Epoch 00186: val_loss did not improve from -700.59410
# Epoch 187/200
# 5000/5000 [==============================] - 3s 693us/step - loss: -724.2872 - val_loss: -701.4600
#
# Epoch 00187: val_loss improved from -700.59410 to -701.46000, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 188/200
# 5000/5000 [==============================] - 3s 683us/step - loss: -724.9814 - val_loss: -700.8151
#
# Epoch 00188: val_loss did not improve from -701.46000
# Epoch 189/200
# 5000/5000 [==============================] - 3s 669us/step - loss: -725.3856 - val_loss: -701.2676
#
# Epoch 00189: val_loss did not improve from -701.46000
# Epoch 190/200
# 5000/5000 [==============================] - 3s 641us/step - loss: -725.4511 - val_loss: -701.1735
#
# Epoch 00190: val_loss did not improve from -701.46000
# Epoch 191/200
# 5000/5000 [==============================] - 3s 660us/step - loss: -725.9178 - val_loss: -701.7265
#
# Epoch 00191: val_loss improved from -701.46000 to -701.72650, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 192/200
# 5000/5000 [==============================] - 3s 683us/step - loss: -726.4429 - val_loss: -701.6943
#
# Epoch 00192: val_loss did not improve from -701.72650
# Epoch 193/200
# 5000/5000 [==============================] - 3s 663us/step - loss: -727.5309 - val_loss: -702.6510
#
# Epoch 00193: val_loss improved from -701.72650 to -702.65100, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 194/200
# 5000/5000 [==============================] - 3s 659us/step - loss: -727.2292 - val_loss: -703.1616
#
# Epoch 00194: val_loss improved from -702.65100 to -703.16158, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 195/200
# 5000/5000 [==============================] - 3s 655us/step - loss: -727.9351 - val_loss: -703.2430
#
# Epoch 00195: val_loss improved from -703.16158 to -703.24300, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 196/200
# 5000/5000 [==============================] - 3s 651us/step - loss: -728.5664 - val_loss: -703.4917
#
# Epoch 00196: val_loss improved from -703.24300 to -703.49172, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 197/200
# 5000/5000 [==============================] - 3s 671us/step - loss: -727.9211 - val_loss: -703.6856
#
# Epoch 00197: val_loss improved from -703.49172 to -703.68563, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5
# Epoch 198/200
# 5000/5000 [==============================] - 3s 654us/step - loss: -728.3737 - val_loss: -702.8067
#
# Epoch 00198: val_loss did not improve from -703.68563
# Epoch 199/200
# 5000/5000 [==============================] - 3s 659us/step - loss: -728.9968 - val_loss: -703.3212
#
# Epoch 00199: val_loss did not improve from -703.68563
# Epoch 200/200
# 5000/5000 [==============================] - 3s 655us/step - loss: -729.5289 - val_loss: -704.8053
#
# Epoch 00200: val_loss improved from -703.68563 to -704.80534, saving model to /Users/shreyajain/PycharmProjects/textGeneration/VAE_keras/checkpoints/pynb/model.h5

# %%
# some matrix magic
def sent_parse(sentence, mat_shape):
    data_concat = []
    word_vecs = vectorize_sentences(sentence)
    for x in word_vecs:
        data_concat.append(list(itertools.chain.from_iterable(x)))
    zero_matr = np.zeros(mat_shape)
    zero_matr[0] = np.array(data_concat)
    return zero_matr

# %%
# input: original dimension sentence vector
# output: text
def print_sentence_with_w2v(sent_vect):
    word_sent = ''
    tocut = sent_vect
    for i in range (int(len(sent_vect)/300)):
        word_sent += w2v.most_similar(positive=[tocut[:300]], topn=1)[0][0]
        word_sent += ' '
        tocut = tocut[300:]
    print(word_sent)

# %%
# input: encoded sentence vector
# output: encoded sentence vector in dataset with highest cosine similarity
def find_similar_encoding(sent_vect):
    all_cosine = []
    for sent in sent_encoded:
        result = 1 - spatial.distance.cosine(sent_vect, sent)
        all_cosine.append(result)
    data_array = np.array(all_cosine)
    maximum = data_array.argsort()[-3:][::-1][1]
    new_vec = sent_encoded[maximum]
    return new_vec

# %%
# input: two points, integer n
# output: n equidistant points on the line between the input points (inclusive)
def shortest_homology(point_one, point_two, num):
    dist_vec = point_two - point_one
    sample = np.linspace(0, 1, num, endpoint = True)
    hom_sample = []
    for s in sample:
        hom_sample.append(point_one + s * dist_vec)
    return hom_sample

# %%
# input: two written sentences, VAE batch-size, dimension of VAE input
# output: the function embeds the sentences in latent-space, and then prints their generated text representations
# along with the text representations of several points in between them
def sent_2_sent(sent1,sent2, batch, dim):
    a = sent_parse([sent1], (batch,dim))
    b = sent_parse([sent2], (batch,dim))
    encode_a = encoder.predict(a, batch_size = batch)
    encode_b = encoder.predict(b, batch_size = batch)
    test_hom = hom_shortest(encode_a[0], encode_b[0], 5)
    
    for point in test_hom:
        p = generator.predict(np.array([point]))[0]
        print_sentence(p)

# %%
print_sentence_with_w2v(train[1])
print_sentence_with_w2v(train[2])
# Out:
# oh look sir beware the hatchway thank ye man .
# humph harriet ' s ready wit all the better .

# %%
print ("train[1] ", len(train[1]))
# Out:
# train[1]  3000

# %%
sent_encoded = encoder.predict(np.array(train), batch_size = 500)

# %%
sent_decoded = generator.predict(sent_encoded)

# %%
test_hom = shortest_homology(sent_encoded[3], sent_encoded[10], 5)
for point in test_hom:
    p = generator.predict(np.array([point]))[0]
    print_sentence_with_w2v(p)
# Out:
# 3 pct of the days 170 000 days 39 .
# 3 pct of the october 169 000 thousand remaining .
# 4 pct of the october 169 thousand thousand eligible .
# american th texas of washington ended equal the industrial .
# george hence u.s. and usa belonged a the kinds .

# %%
test_hom = shortest_homology(sent_encoded[2], sent_encoded[1500], 20)
for point in test_hom:
    p = generator.predict(np.array([find_similar_encoding(point)]))[0]
    print_sentence_with_w2v(p)
# Out:
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# oh ald tell Scot feelin too just just pity .
# i couldn eh t able a too just hardly .
# i couldn eh t able a too just hardly .
# oh ald ' s feeling either feeling of taste .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
# he was a moment of the feeling without something .
